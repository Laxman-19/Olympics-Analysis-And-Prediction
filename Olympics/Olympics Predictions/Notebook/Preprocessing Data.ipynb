# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/athlete_events.csv')
region_df = pd.read_csv('../Data/noc_regions.csv')

# %%
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
tokyo_df = pd.read_csv('../Data/tokyo_dfset.csv', encoding='latin1')

# %%
tokyo_df.head(3)
# Out:
#    Unnamed: 0     Code             Name  Gender  Age  NOC Country Discipline  \
# 0           1  1346266  AALERUD Katrine  Female   26  NOR  Norway        CRD
# 1           2  1346266  AALERUD Katrine  Female   26  NOR  Norway        CRD
# 2           3  1355250      ABAD Nestor    Male   28  ESP   Spain        GAR
#
#                  Sport                          Event  Rank Medal
# 0         Cycling Road              Women's Road Race  37.0   NaN
# 1         Cycling Road  Women's Individual Time Trial  20.0   NaN
# 2  Artistic Gymnastics               Men's All-Around   NaN   NaN

# %%
df = df[df['Season'] == 'Summer']
df = df.merge(region_df, on='NOC', how='left')
df.drop_duplicates(inplace=True)

df = df.drop(['ID','Team','Games','Season','City','Event','notes'],axis=1)
df = df.rename(columns={'Sex':'Gender','region':'Country'})
df['Gender'] = df['Gender'].map( {'M':'Male','F':'Female',} )
df = df[['Name','Gender','Age','Height','Weight','Year','Country','NOC','Sport','Medal']]

# %%
tokyo_df = tokyo_df.drop(['Unnamed: 0','Code','Discipline','Event','Rank'],axis=1)
tokyo_df['Year'] = 2020
tokyo_df = tokyo_df[['Name','Gender','Age','Year','Country','NOC','Sport','Medal']]

# %%
df.head(2)
# Out:
#         Name Gender   Age  Height  Weight  Year Country  NOC       Sport Medal
# 0  A Dijiang   Male  24.0   180.0    80.0  1992   China  CHN  Basketball   NaN
# 1   A Lamusi   Male  23.0   170.0    60.0  2012   China  CHN        Judo   NaN

# %%
tokyo_df.head(2)
# Out:
#               Name  Gender  Age  Year Country  NOC         Sport Medal
# 0  AALERUD Katrine  Female   26  2020  Norway  NOR  Cycling Road   NaN
# 1  AALERUD Katrine  Female   26  2020  Norway  NOR  Cycling Road   NaN

# %%
result_df = pd.concat([df, tokyo_df], axis=0)
result_df.reset_index(drop=True, inplace=True)

# %%
result_df.head(2)
# Out:
#         Name Gender   Age  Height  Weight  Year Country  NOC       Sport Medal
# 0  A Dijiang   Male  24.0   180.0    80.0  1992   China  CHN  Basketball   NaN
# 1   A Lamusi   Male  23.0   170.0    60.0  2012   China  CHN        Judo   NaN

# %%
x = pd.get_dummies(result_df['Medal']).astype(int)
result_df = pd.concat([result_df,x], axis=1)

result_df['Total'] = result_df['Gold'] + result_df['Silver'] + result_df['Bronze']
result_df = result_df[['Name','Gender','Age','Height','Weight','Year','Country','NOC','Sport','Medal','Gold','Silver','Bronze','Total']]

# %%
result_df.head(2)
# Out:
#         Name Gender   Age  Height  Weight  Year Country  NOC       Sport  \
# 0  A Dijiang   Male  24.0   180.0    80.0  1992   China  CHN  Basketball
# 1   A Lamusi   Male  23.0   170.0    60.0  2012   China  CHN        Judo
#
#   Medal  Gold  Silver  Bronze  Total
# 0   NaN     0       0       0      0
# 1   NaN     0       0       0      0

# %%
# result_df.to_csv('processed_data.csv', index=False)
